# %%
import numpy as np
import pandas as pd
from collections import Counter
from plotnine import *

# %%
vec = np.load('rank_matrix.npy')

# %%
vec.shape
# Out:
# (25808,)

# %%
print(np.min(lvec))
print(np.percentile(lvec, 2))
m = np.min(lvec)
# Out:
# -12.055559785250873
# -12.055559785250873

# %%
m
# Out:
# -12.055559785250873

# %%
lv2 = np.asarray([x for x in lvec if abs(x - m) > 1e-5])

# %%
len(lv2), len(lvec)
# Out:
# (15472, 25808)

# %%
lvec = np.log(vec)
lv3 = np.log(lvec - np.min(lvec) + 1e-5)

# %%
df = pd.DataFrame({'pr': pd.Series(lv3)})

# %%
(
    ggplot(df, aes('pr'))
    + geom_histogram()
    + ggtitle("'loglog' of PageRank (probability)")
)
# Out:
# /home/george/inst/anaconda3/lib/python3.6/site-packages/plotnine/stats/stat_bin.py:95: UserWarning: 'stat_bin()' using 'bins = 19'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']))
# <ggplot: (-9223363256341585576)>

# %%
df = pd.DataFrame({'pr': pd.Series(lvec)})

# %%
(
    ggplot(df, aes('pr'))
    + geom_histogram()
    + ggtitle("log of PageRank (probability)")
)
# Out:
# /home/george/inst/anaconda3/lib/python3.6/site-packages/plotnine/stats/stat_bin.py:95: UserWarning: 'stat_bin()' using 'bins = 292'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']))
# <ggplot: (8780513584581)>
